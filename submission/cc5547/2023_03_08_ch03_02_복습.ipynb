# %% [markdown]
# <a href="https://colab.research.google.com/github/cc5547/Python/blob/main/submission/cc5547/2023_03_08_ch03_02_%EB%B3%B5%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 클래스 (Class : Classification)

# %%
class Teacher: # class 클래스이름:
    def __init__(self): # def __init__(self): 생성자
        self.name = "이명직"

# %%
lee = Teacher() # 클래스() : 해당 클래스를 기반으로 하는 인스턴스(객체)를 생성해주겠다
# 클래스 : 특정한 객체를 만들 수 있는 설계도
# 인스턴스 : 클래스로 만들어진 객체
# 객체 : 특정한 기능이나 값들의 묶음
lee

# %%
lee.name # 인스터스의 속성.
# Out:
# '이명직'

# %%
class Teacher: # class 클래스이름:
    def __init__(self): # def __init__(self): 생성자
        self.name = "이명직"
    
    # 클래스에 속한 함수(기능) -> 메소드, 메서드. (method)
    def lesson(self): # def 메소드이름(self)
        print("수업을 시작하겠습니다!")

# %%
lee = Teacher()
lee.lesson() # 인스턴스.메소드명()
# Out:
# 수업을 시작하겠습니다!

# %%
class Teacher: # class 클래스이름:
    def __init__(self, name): # def __init__(self, 매개변수 - parameter): 생성자 <- 인자(argment) (외부)
        # self.name = "이명직"
        self.name = name
    
    # 클래스에 속한 함수(기능) -> 메소드, 메서드. (method)
    def lesson(self, time, *args, comment="뭘 하면 좋을까요", **kwargs): # def 메소드이름(self)
        # 자기소개를 한다 (인스턴스->name)
        print(f"제 이름은 {self.name}입니다.")
        # 수업 시간을 알려준다 (매개변수->time)
        print(f"오늘의 수업시간은 {time:.2f}시간입니다.")
        # 수업 과목 목록을 돌려준다 (args -> for반복)
        print(f"오늘의 수업 과목은 ")
        # for v in args: # *args -> 튜플 -> 시퀀스 -> for로 반복이 가능
        # enumerate : 시퀀스형 객체를 '인덱스, 값' 형태의 튜플로 원소들을 바꿔줌
        for i, v in enumerate(args): # *args -> 튜플 -> 시퀀스 -> for로 반복이 가능
            # 각각의 요소(element)를 v라는 변수 이름으로 받겠다
            # v는 루프가 한 번 돌때마다 순서대로 새로운 요소 값을 받는다
            print(i, v)
            # print(v)
        print("입니다")
        print("수업을 시작하겠습니다!")
        print(comment)
        # kwargs -> 수강생명:질문
        for k, v in kwargs.items():
            print(f"{k}님이 질문하셨네요")
            print(f"{v}에 대해서 답해드릴게요")
            print("실은 저도 잘 몰라요")

# %%
import math

# lee = Teacher() # name -> name이라고 하는 매개변수를 입력안하면 나 실행 안할꺼야!
lee = Teacher('이단단') # name -> name이라고 하는 매개변수를 입력안하면 나 실행 안할꺼야!
print(lee.name)
# lee.lesson() # time
lee.lesson(math.pi) # time
# Out:
# 이단단
# 제 이름은 이단단입니다.
# 오늘의 수업시간은 3.14시간입니다.
# 오늘의 수업 과목은  입니다
# 수업을 시작하겠습니다!
# 뭘 하면 좋을까요

# %%
lee.lesson(math.pi, "자바", "자바스크립트", "Numpy")
# Out:
# 제 이름은 이단단입니다.
# 오늘의 수업시간은 3.14시간입니다.
# 오늘의 수업 과목은  0 자바
# 1 자바스크립트
# 2 Numpy
# 입니다
# 수업을 시작하겠습니다!
# 뭘 하면 좋을까요

# %%
lee.lesson(math.pi,
           "자바", "자바스크립트", "Numpy",
           comment="오늘은 기분이 참 좋네요!",
           john="강사님 타자가 너무 빨라요",
           james="강사님 수업 진도만 나가면 안될까요",
           kate="강사님 깃허브 꼬였어요")
# Out:
# 제 이름은 이단단입니다.
# 오늘의 수업시간은 3.14시간입니다.
# 오늘의 수업 과목은  0 자바
# 1 자바스크립트
# 2 Numpy
# 입니다
# 수업을 시작하겠습니다!
# 오늘은 기분이 참 좋네요!
# john님이 질문하셨네요
# 강사님 타자가 너무 빨라요에 대해서 답해드릴게요
# 실은 저도 잘 몰라요
# james님이 질문하셨네요
# 강사님 수업 진도만 나가면 안될까요에 대해서 답해드릴게요
# 실은 저도 잘 몰라요
# kate님이 질문하셨네요
# 강사님 깃허브 꼬였어요에 대해서 답해드릴게요
# 실은 저도 잘 몰라요

# %%
class CheonBeer:
    counter=1 # 클래스들이 모두 공유
    
    def __init__(self):
        print(f"축하합니다! {CheonBeer.counter}호점을 개점했습니다!")
        CheonBeer.counter += 1 # 1을 더해주고 그 값을 해당 변수에 다시 대입

# %%
s1 = CheonBeer()
s1.counter
# Out:
# 축하합니다! 1호점을 개점했습니다!
# 2

# %%
s2 = CheonBeer()
s1.counter, s2.counter
# Out:
# 축하합니다! 2호점을 개점했습니다!
# (3, 3)

# %%
# 클래스 속성
# 클래스 -> 인스턴스 -> 개별 인스터스 속성

class CheonBeer:
    counter=1 # 클래스들이 모두 공유
    
    def __init__(self):
        print(f"축하합니다! {self.counter}호점을 개점했습니다!")
        self.counter += 1 # 1을 더해주고 그 값을 해당 변수에 다시 대입

# %%
s1 = CheonBeer()
s1.counter
# Out:
# 축하합니다! 1호점을 개점했습니다!
# 2

# %%
s2 = CheonBeer()
s1.counter, s2.counter
# Out:
# 축하합니다! 1호점을 개점했습니다!
# (2, 2)

# %%
class CheonBeer:
    counter=1 # 클래스들이 모두 공유
    
    def __init__(self):
        print(f"축하합니다! {CheonBeer.counter}호점을 개점했습니다!") # self로 지정해서 하면, 클래스간 공유를 안함
        self.my_counter = CheonBeer.counter
        CheonBeer.counter += 1 # 1을 더해주고 그 값을 해당 변수에 다시 대입

# %%
s1 = CheonBeer()
s2 = CheonBeer()
s1.counter, s2.counter, s1.my_counter, s2.my_counter
# Out:
# 축하합니다! 1호점을 개점했습니다!
# 축하합니다! 2호점을 개점했습니다!
# (3, 3, 1, 2)

# %%
class ManBeer(CheonBeer): # class 하위클래스(상위클래스):
    pass

# %%
a1 = ManBeer()
a1.counter, a1.my_counter
# Out:
# 축하합니다! 3호점을 개점했습니다!
# (4, 3)

# %%
class ManBeer(CheonBeer): # class 하위클래스(상위클래스):
    def __init__(self, prize, visitor_count): # 덮어씌워서 다시 메소드를 작성하는 것 -> 메소드 오버라이딩
        print(f"{visitor_count}번째 손님에게 {prize}를 드립니다")

# %%
a1 = ManBeer("아이폰", 10000)
a1.counter, a1.my_counter
# Out:
# 10000번째 손님에게 아이폰를 드립니다
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-eab1d7d8cb4a> in <module>
#       1 a1 = ManBeer("아이폰", 10000)
# ----> 2 a1.counter, a1.my_counter
#
# AttributeError: 'ManBeer' object has no attribute 'my_counter'

# %%
class ManBeer(CheonBeer): # class 하위클래스(상위클래스):
    def __init__(self, prize, visitor_count): # 덮어씌워서 다시 메소드를 작성하는 것 -> 메소드 오버라이딩
        # super(ManBeer, self).__init__()
        super().__init__() # super(본인클래스, self): 자기자신의 부모를 호출 -> self
        print(f"{visitor_count}번째 손님에게 {prize}를 드립니다")

# %%
a1 = ManBeer("아이폰", 10000)
a1.counter, a1.my_counter
# Out:
# 축하합니다! 3호점을 개점했습니다!
# 10000번째 손님에게 아이폰를 드립니다
# (4, 3)

# %%
class ManWine(ManBeer):
    def __init__(self, msg):
        super().__init__() # ManBeer를 super로 쓰게 됨
        print(f"행운의 포춘쿠키 : {msg}")

# %%
a2 = ManWine("주변 사람에게 잘 하세요")
a2.counter, a2.my_counter
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-966e30c5cb61> in <module>
# ----> 1 a2 = ManWine("주변 사람에게 잘 하세요")
#       2 a2.counter, a2.my_counter
#
# <ipython-input-76-ca537d7d3b42> in __init__(self, msg)
#       1 class ManWine(ManBeer):
#       2     def __init__(self, msg):
# ----> 3         super().__init__() # ManBeer를 super로 쓰게 됨
#       4         print(f"행운의 포춘쿠키 : {msg}")
#
# TypeError: __init__() missing 2 required positional arguments: 'prize' and 'visitor_count'

# %%
class ManWine(ManBeer):
    def __init__(self, msg):
        super(ManBeer, self).__init__() # ManBeer의 부모 -> CheonBeer를 호출
        print(f"행운의 포춘쿠키 : {msg}")

# %%
a2 = ManWine("주변 사람에게 잘 하세요")
a2.counter, a2.my_counter
# Out:
# 축하합니다! 3호점을 개점했습니다!
# 행운의 포춘쿠키 : 주변 사람에게 잘 하세요
# (4, 3)
