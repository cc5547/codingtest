# %% [markdown]
# <a href="https://colab.research.google.com/github/cc5547/Python/blob/main/submission/cc5547/2023_03_07_CH03_01_%EB%B3%B5%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 함수

# %%
import random

subjects = [
    "여러분, 취업 준비하셔야해요!",
    "자격증은 스터디 짜셨어요?",
    "왜 깃허브에 회고 안 올려요??",
    "사람들이 왜 자꾸 나가지 ㅠㅠ",
    "오늘 주식은 많이 오르지 않네요",
]
learning = {
    "문자열": "split, replace...",
    "리스트": "append, extend...",
    "딕셔너리": "get, update..."
}

def study(): # 상위모듈
    energy = random.randint(1, 10)
    print(hello(energy)) # 하위모듈
    energy -= 1
    # random.choices(뽑히는 대상-모집단, k=뽑는수)
    chat(energy, *subjects, k=2) # * 리스트 언패킹
    lecture(**learning)
    print(*bye(), sep=' ')

# def hello():
#     return "좋은 아침입니다 여러분"

# def chat(repeat, *args):
#     pass

# def lecture():
#     pass

def bye():
    return "10분 쉬겠습니다", "PR 보내주세요"

# %%
def hello(energy=5):
    # 0 ~ 10
    if energy == 10:
        return "여러분! 오늘 제가 커피 쏠까요?" # return -> 더 이상 뒤로 진행 X
    if energy >= 5:
        return "^_^ 오늘 점심메뉴 알려드릴까요?"
    return "... (무표정)"

# %%
def chat(repeat, *args, k=2):
    for i in range(repeat):
        print(f"* 제가 {i+1}번째 이야기하는 것 같은데...")
        # for j in args:
        #     print(j)
        choices = random.choices(args, k=k)
        for j in choices:
            print(f"** {j}")

# %%
def lecture(**kwargs):
    # for k, v in kwargs.items():
    #     print('*** 자, 진도 나가겠습니다')
    #     print(f'*** {k}에서 {v}를 배워봅시다')
    for i, (k, v) in enumerate(kwargs.items()):
        print(f'*** 자, 진도 {i+1}번째 나가겠습니다')
        print(f'*** {k}에서 {v}를 배워봅시다')

# %%
study()
# Out:
# ^_^ 오늘 점심메뉴 알려드릴까요?
# * 제가 1번째 이야기하는 것 같은데...
# ** 여러분, 취업 준비하셔야해요!
# ** 자격증은 스터디 짜셨어요?
# * 제가 2번째 이야기하는 것 같은데...
# ** 자격증은 스터디 짜셨어요?
# ** 왜 깃허브에 회고 안 올려요??
# * 제가 3번째 이야기하는 것 같은데...
# ** 오늘 주식은 많이 오르지 않네요
# ** 사람들이 왜 자꾸 나가지 ㅠㅠ
# * 제가 4번째 이야기하는 것 같은데...
# ** 자격증은 스터디 짜셨어요?
# ** 오늘 주식은 많이 오르지 않네요
# *** 자, 진도 1번째 나가겠습니다
# *** 문자열에서 split, replace...를 배워봅시다
# *** 자, 진도 2번째 나가겠습니다
# *** 리스트에서 append, extend...를 배워봅시다
# *** 자, 진도 3번째 나가겠습니다
# *** 딕셔너리에서 get, update...를 배워봅시다
# 10분 쉬겠습니다 PR 보내주세요
